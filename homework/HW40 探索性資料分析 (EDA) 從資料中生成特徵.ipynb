# %% [markdown]
# ## 今天的作業
# 在鐵達尼資料集中，今天我們專注觀察變數之間的相關性，以Titanic_train.csv 中，首先將有遺失值的數值刪除，我們取 Titanic_train.csv 的年齡資料，試著將課堂中所學的方法應用上去。
#
# * Q1: 產生一個新的變數(Age_above65_) Age>=65為 'Y'，其餘為'N'。
# * Q2: 添加女性和男性，產生一個新的變數(Age_above65_female)，女性或Age>=65為'Y'，其餘為'N'。
# *  Q3: 透過昨天課程的內容，驗證產生的兩個新變數，哪一個和目標變數(Survived_cate)的相關性較高?

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline


#顯示所有行
pd.set_option('display.max_columns', None)
#顯示所有列
pd.set_option('display.max_rows', None)
#顯示行設定
pd.set_option('max_colwidth',100)

import pingouin as pg
import researchpy
# Out:
# 0.23.1

# %% [markdown]
# ## 讀入資料

# %%
df_train = pd.read_csv("Titanic_train.csv")
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#1.產稱一個新的變數 Survived_cate ，資料型態傳換成類別型態      
#2.把題目中的 Survived 用 Survived_cate 來做分析    
df_train['Survived_cate']=df_train['Survived']
df_train['Survived_cate']=df_train['Survived_cate'].astype('object')
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    891 non-null    int64
#  1   Survived       891 non-null    int64
#  2   Pclass         891 non-null    int64
#  3   Name           891 non-null    object
#  4   Sex            891 non-null    object
#  5   Age            714 non-null    float64
#  6   SibSp          891 non-null    int64
#  7   Parch          891 non-null    int64
#  8   Ticket         891 non-null    object
#  9   Fare           891 non-null    float64
#  10  Cabin          204 non-null    object
#  11  Embarked       889 non-null    object
#  12  Survived_cate  891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB
# None

# %%
#我們先把遺失值刪除
## 取出資料後，把遺失值刪除
complete_data=df_train[['Age','Survived_cate','Sex']].dropna()
display(complete_data)
# Out:
#        Age Survived_cate     Sex
# 0    22.00             0    male
# 1    38.00             1  female
# 2    26.00             1  female
# 3    35.00             1  female
# 4    35.00             0    male
# 6    54.00             0    male
# 7     2.00             0    male
# 8    27.00             1  female
# 9    14.00             1  female
# 10    4.00             1  female
# 11   58.00             1  female
# 12   20.00             0    male
# 13   39.00             0    male
# 14   14.00             0  female
# 15   55.00             1  female
# 16    2.00             0    male
# 18   31.00             0  female
# 20   35.00             0    male
# 21   34.00             1    male
# 22   15.00             1  female
# 23   28.00             1    male
# 24    8.00             0  female
# 25   38.00             1  female
# 27   19.00             0    male
# 30   40.00             0    male
# 33   66.00             0    male
# 34   28.00             0    male
# 35   42.00             0    male
# 37   21.00             0    male
# 38   18.00             0  female
# 39   14.00             1  female
# 40   40.00             0  female
# 41   27.00             0  female
# 43    3.00             1  female
# 44   19.00             1  female
# 49   18.00             0  female
# 50    7.00             0    male
# 51   21.00             0    male
# 52   49.00             1  female
# 53   29.00             1  female
# 54   65.00             0    male
# 56   21.00             1  female
# 57   28.50             0    male
# 58    5.00             1  female
# 59   11.00             0    male
# 60   22.00             0    male
# 61   38.00             1  female
# 62   45.00             0    male
# 63    4.00             0    male
# 66   29.00             1  female
# 67   19.00             0    male
# 68   17.00             1  female
# 69   26.00             0    male
# 70   32.00             0    male
# 71   16.00             0  female
# 72   21.00             0    male
# 73   26.00             0    male
# 74   32.00             1    male
# 75   25.00             0    male
# 78    0.83             1    male
# 79   30.00             1  female
# 80   22.00             0    male
# 81   29.00             1    male
# 83   28.00             0    male
# 84   17.00             1  female
# 85   33.00             1  female
# 86   16.00             0    male
# 88   23.00             1  female
# 89   24.00             0    male
# 90   29.00             0    male
# 91   20.00             0    male
# 92   46.00             0    male
# 93   26.00             0    male
# 94   59.00             0    male
# 96   71.00             0    male
# 97   23.00             1    male
# 98   34.00             1  female
# 99   34.00             0    male
# 100  28.00             0  female
# 102  21.00             0    male
# 103  33.00             0    male
# 104  37.00             0    male
# 105  28.00             0    male
# 106  21.00             1  female
# 108  38.00             0    male
# 110  47.00             0    male
# 111  14.50             0  female
# 112  22.00             0    male
# 113  20.00             0  female
# 114  17.00             0  female
# 115  21.00             0    male
# 116  70.50             0    male
# 117  29.00             0    male
# 118  24.00             0    male
# 119   2.00             0  female
# 120  21.00             0    male
# 122  32.50             0    male
# 123  32.50             1  female
# 124  54.00             0    male
# 125  12.00             1    male
# 127  24.00             1    male
# 129  45.00             0    male
# 130  33.00             0    male
# 131  20.00             0    male
# 132  47.00             0  female
# 133  29.00             1  female
# 134  25.00             0    male
# 135  23.00             0    male
# 136  19.00             1  female
# 137  37.00             0    male
# 138  16.00             0    male
# 139  24.00             0    male
# 141  22.00             1  female
# 142  24.00             1  female
# 143  19.00             0    male
# 144  18.00             0    male
# 145  19.00             0    male
# 146  27.00             1    male
# 147   9.00             0  female
# 148  36.50             0    male
# 149  42.00             0    male
# 150  51.00             0    male
# 151  22.00             1  female
# 152  55.50             0    male
# 153  40.50             0    male
# 155  51.00             0    male
# 156  16.00             1  female
# 157  30.00             0    male
# 160  44.00             0    male
# 161  40.00             1  female
# 162  26.00             0    male
# 163  17.00             0    male
# 164   1.00             0    male
# 165   9.00             1    male
# 167  45.00             0  female
# 169  28.00             0    male
# 170  61.00             0    male
# 171   4.00             0    male
# 172   1.00             1  female
# 173  21.00             0    male
# 174  56.00             0    male
# 175  18.00             0    male
# 177  50.00             0  female
# 178  30.00             0    male
# 179  36.00             0    male
# 182   9.00             0    male
# 183   1.00             1    male
# 184   4.00             1  female
# 187  45.00             1    male
# 188  40.00             0    male
# 189  36.00             0    male
# 190  32.00             1  female
# 191  19.00             0    male
# 192  19.00             1  female
# 193   3.00             1    male
# 194  44.00             1  female
# 195  58.00             1  female
# 197  42.00             0    male
# 199  24.00             0  female
# 200  28.00             0    male
# 202  34.00             0    male
# 203  45.50             0    male
# 204  18.00             1    male
# 205   2.00             0  female
# 206  32.00             0    male
# 207  26.00             1    male
# 208  16.00             1  female
# 209  40.00             1    male
# 210  24.00             0    male
# 211  35.00             1  female
# 212  22.00             0    male
# 213  30.00             0    male
# 215  31.00             1  female
# 216  27.00             1  female
# 217  42.00             0    male
# 218  32.00             1  female
# 219  30.00             0    male
# 220  16.00             1    male
# 549   8.00             1    male
# 550  17.00             1    male
# 551  27.00             0    male
# 553  22.00             1    male
# 554  22.00             1  female
# 555  62.00             0    male
# 556  48.00             1  female
# 558  39.00             1  female
# 559  36.00             1  female
# 561  40.00             0    male
# 562  28.00             0    male
# 565  24.00             0    male
# 566  19.00             0    male
# 567  29.00             0  female
# 569  32.00             1    male
# 570  62.00             1    male
# 571  53.00             1  female
# 572  36.00             1    male
# 574  16.00             0    male
# 575  19.00             0    male
# 576  34.00             1  female
# 577  39.00             1  female
# 579  32.00             1    male
# 580  25.00             1  female
# 581  39.00             1  female
# 582  54.00             0    male
# 583  36.00             0    male
# 585  18.00             1  female
# 586  47.00             0    male
# 587  60.00             1    male
# 588  22.00             0    male
# 590  35.00             0    male
# 591  52.00             1  female
# 592  47.00             0    male
# 594  37.00             0    male
# 595  36.00             0    male
# 597  49.00             0    male
# 599  49.00             1    male
# 600  24.00             1  female
# 603  44.00             0    male
# 604  35.00             1    male
# 605  36.00             0    male
# 606  30.00             0    male
# 607  27.00             1    male
# 608  22.00             1  female
# 609  40.00             1  female
# 610  39.00             0  female
# 614  35.00             0    male
# 615  24.00             1  female
# 616  34.00             0    male
# 617  26.00             0  female
# 618   4.00             1  female
# 619  26.00             0    male
# 620  27.00             0    male
# 621  42.00             1    male
# 622  20.00             1    male
# 623  21.00             0    male
# 624  21.00             0    male
# 625  61.00             0    male
# 626  57.00             0    male
# 627  21.00             1  female
# 628  26.00             0    male
# 630  80.00             1    male
# 631  51.00             0    male
# 632  32.00             1    male
# 634   9.00             0  female
# 635  28.00             1  female
# 636  32.00             0    male
# 637  31.00             0    male
# 638  41.00             0  female
# 640  20.00             0    male
# 641  24.00             1  female
# 642   2.00             0  female
# 644   0.75             1  female
# 645  48.00             1    male
# 646  19.00             0    male
# 647  56.00             1    male
# 649  23.00             1  female
# 651  18.00             1  female
# 652  21.00             0    male
# 654  18.00             0  female
# 655  24.00             0    male
# 657  32.00             0  female
# 658  23.00             0    male
# 659  58.00             0    male
# 660  50.00             1    male
# 661  40.00             0    male
# 662  47.00             0    male
# 663  36.00             0    male
# 664  20.00             1    male
# 665  32.00             0    male
# 666  25.00             0    male
# 668  43.00             0    male
# 670  40.00             1  female
# 671  31.00             0    male
# 672  70.00             0    male
# 673  31.00             1    male
# 675  18.00             0    male
# 676  24.50             0    male
# 677  18.00             1  female
# 678  43.00             0  female
# 679  36.00             1    male
# 681  27.00             1    male
# 682  20.00             0    male
# 683  14.00             0    male
# 684  60.00             0    male
# 685  25.00             0    male
# 686  14.00             0    male
# 687  19.00             0    male
# 688  18.00             0    male
# 689  15.00             1  female
# 690  31.00             1    male
# 691   4.00             1  female
# 693  25.00             0    male
# 694  60.00             0    male
# 695  52.00             0    male
# 696  44.00             0    male
# 698  49.00             0    male
# 699  42.00             0    male
# 700  18.00             1  female
# 701  35.00             1    male
# 702  18.00             0  female
# 703  25.00             0    male
# 704  26.00             0    male
# 705  39.00             0    male
# 706  45.00             1  female
# 707  42.00             1    male
# 708  22.00             1  female
# 710  24.00             1  female
# 712  48.00             1    male
# 713  29.00             0    male
# 714  52.00             0    male
# 715  19.00             0    male
# 716  38.00             1  female
# 717  27.00             1  female
# 719  33.00             0    male
# 720   6.00             1  female
# 721  17.00             0    male
# 722  34.00             0    male
# 723  50.00             0    male
# 724  27.00             1    male
# 725  20.00             0    male
# 726  30.00             1  female
# 728  25.00             0    male
# 729  25.00             0  female
# 730  29.00             1  female
# 731  11.00             0    male
# 733  23.00             0    male
# 734  23.00             0    male
# 735  28.50             0    male
# 736  48.00             0  female
# 737  35.00             1    male
# 741  36.00             0    male
# 742  21.00             1  female
# 743  24.00             0    male
# 744  31.00             1    male
# 745  70.00             0    male
# 746  16.00             0    male
# 747  30.00             1  female
# 748  19.00             0    male
# 749  31.00             0    male
# 750   4.00             1  female
# 751   6.00             1    male
# 752  33.00             0    male
# 753  23.00             0    male
# 754  48.00             1  female
# 755   0.67             1    male
# 756  28.00             0    male
# 757  18.00             0    male
# 758  34.00             0    male
# 759  33.00             1  female
# 761  41.00             0    male
# 762  20.00             1    male
# 763  36.00             1  female
# 764  16.00             0    male
# 765  51.00             1  female
# 767  30.50             0  female
# 769  32.00             0    male
# 770  24.00             0    male
# 771  48.00             0    male
# 772  57.00             0  female
# 774  54.00             1  female
# 775  18.00             0    male
# 777   5.00             1  female
# 779  43.00             1  female
# 780  13.00             1  female
# 781  17.00             1  female
# 782  29.00             0    male
# 784  25.00             0    male
# 785  25.00             0    male
# 786  18.00             1  female
# 787   8.00             0    male
# 788   1.00             1    male
# 789  46.00             0    male
# 791  16.00             0    male
# 794  25.00             0    male
# 795  39.00             0    male
# 796  49.00             1  female
# 797  31.00             1  female
# 798  30.00             0    male
# 799  30.00             0  female
# 800  34.00             0    male
# 801  31.00             1  female
# 802  11.00             1    male
# 803   0.42             1    male
# 804  27.00             1    male
# 805  31.00             0    male
# 806  39.00             0    male
# 807  18.00             0  female
# 808  39.00             0    male
# 809  33.00             1  female
# 810  26.00             0    male
# 811  39.00             0    male
# 812  35.00             0    male
# 813   6.00             0  female
# 814  30.50             0    male
# 816  23.00             0  female
# 817  31.00             0    male
# 818  43.00             0    male
# 819  10.00             0    male
# 820  52.00             1  female
# 821  27.00             1    male
# 822  38.00             0    male
# 823  27.00             1  female
# 824   2.00             0    male
# 827   1.00             1    male
# 829  62.00             1  female
# 830  15.00             1  female
# 831   0.83             1    male
# 833  23.00             0    male
# 834  18.00             0    male
# 835  39.00             1  female
# 836  21.00             0    male
# 838  32.00             1    male
# 840  20.00             0    male
# 841  16.00             0    male
# 842  30.00             1  female
# 843  34.50             0    male
# 844  17.00             0    male
# 845  42.00             0    male
# 847  35.00             0    male
# 848  28.00             0    male
# 850   4.00             0    male
# 851  74.00             0    male
# 852   9.00             0  female
# 853  16.00             1  female
# 854  44.00             0  female
# 855  18.00             1  female
# 856  45.00             1  female
# 857  51.00             1    male
# 858  24.00             1  female
# 860  41.00             0    male
# 861  21.00             0    male
# 862  48.00             1  female
# 864  24.00             0    male
# 865  42.00             1  female
# 866  27.00             1  female
# 867  31.00             0    male
# 869   4.00             1    male
# 870  26.00             0    male
# 871  47.00             1  female
# 872  33.00             0    male
# 873  47.00             0    male
# 874  28.00             1  female
# 875  15.00             1  female
# 876  20.00             0    male
# 877  19.00             0    male
# 879  56.00             1  female
# 880  25.00             1  female
# 881  33.00             0    male
# 882  22.00             0  female
# 883  28.00             0    male
# 884  25.00             0    male
# 885  39.00             0  female
# 886  27.00             0    male
# 887  19.00             1  female
# 889  26.00             1    male
# 890  32.00             0    male

# %% [markdown]
# ### Q1: 產生一個新的變數(Age_above65_) Age>=65為 'Y'，其餘為'N'。

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline


#顯示所有行
pd.set_option('display.max_columns', None)
#顯示所有列
pd.set_option('display.max_rows', None)
#顯示行設定
pd.set_option('max_colwidth',100)

import pingouin as pg
import researchpy   
df_train = pd.read_csv("Titanic_train.csv")
df_train['Survived_cate']=df_train['Survived']
df_train['Survived_cate']=df_train['Survived_cate'].astype('object')
complete_data=df_train[['Age','Survived_cate','Sex']].dropna()
complete_data['Age_above65_'] = complete_data['Age'].apply(lambda x:'Y' if x >=65 else 'N')
complete_data.head()
# Out:
# 0.24.2
#     Age Survived_cate     Sex Age_above65_
# 0  22.0             0    male            N
# 1  38.0             1  female            N
# 2  26.0             1  female            N
# 3  35.0             1  female            N
# 4  35.0             0    male            N

# %% [markdown]
# ### Q2: 添加女性和男性，產生一個新的變數(Age_above65_female)，女性或Age>=65為'Y'，其餘為'N'。
# * 暗示: 觀看下面影片找答案，https://www.youtube.com/watch?v=X2d-wUt5azY

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline


#顯示所有行
pd.set_option('display.max_columns', None)
#顯示所有列
pd.set_option('display.max_rows', None)
#顯示行設定
pd.set_option('max_colwidth',100)

import pingouin as pg
import researchpy   
df_train = pd.read_csv("Titanic_train.csv")
df_train['Survived_cate']=df_train['Survived']
df_train['Survived_cate']=df_train['Survived_cate'].astype('object')
complete_data=df_train[['Age','Survived_cate','Sex']].dropna()
complete_data['Age_above65_'] = complete_data['Age'].apply(lambda x:'Y' if x >=65 else 'N')
def Age_above65_female1(row):
    if (row.Sex == 'female'):
        return ('Y')
    else: 
        if (row.Age >= 65):
            return ('Y')
        else:
            return ('N')
    

complete_data['Age_above65_female'] = complete_data[['Sex','Age']].apply(Age_above65_female1, axis =1)
complete_data.head()
# Out:
# 0.24.2
#     Age Survived_cate     Sex Age_above65_ Age_above65_female
# 0  22.0             0    male            N                  N
# 1  38.0             1  female            N                  Y
# 2  26.0             1  female            N                  Y
# 3  35.0             1  female            N                  Y
# 4  35.0             0    male            N                  N

# %% [markdown]
# ### Q3: 透過昨天課程的內容，驗證產生的兩個新變數，哪一個和目標變數(Survived_cate)的相關性較高?
# * 提示:
#   首先觀察一下這些變數的資料型態後，再來想要以哪一種判斷倆倆的相關性。

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline


#顯示所有行
pd.set_option('display.max_columns', None)
#顯示所有列
pd.set_option('display.max_rows', None)
#顯示行設定
pd.set_option('max_colwidth',100)

import pingouin as pg
import researchpy   
df_train = pd.read_csv("Titanic_train.csv")
df_train['Survived_cate']=df_train['Survived']
df_train['Survived_cate']=df_train['Survived_cate'].astype('object')
complete_data=df_train[['Age','Survived_cate','Sex']].dropna()
complete_data['Age_above65_'] = complete_data['Age'].apply(lambda x:'Y' if x >=65 else 'N')

def Age_above65_female1(row):
    if (row.Sex == 'female'):
        return ('Y')
    else: 
        if (row.Age >= 65):
            return ('Y')
        else:
            return ('N')
    

complete_data['Age_above65_female'] = complete_data[['Sex','Age']].apply(Age_above65_female1, axis =1)

#都是離散對離散
contTable = pd.crosstab(complete_data['Survived_cate'],complete_data['Age_above65_'])
print(contTable)
df = min(contTable.shape[0], contTable.shape[1]) - 1
crosstab, res = researchpy.crosstab(complete_data['Survived_cate'], complete_data['Age_above65_'], test='chi-square')
print("Cramer's value is",res.loc[2,'results'])
sns.set_style('whitegrid')
sns.countplot(data = complete_data, x = 'Age_above65_', hue = 'Survived_cate')
plt.show()
contTable2 = pd.crosstab(complete_data['Survived_cate'], complete_data['Age_above65_female'])
print(contTable)
df = min(contTable2.shape[0], contTable2.shape[1]) - 1
crosstab2, res2 = researchpy.crosstab(complete_data['Survived_cate'], complete_data['Age_above65_female'], test='chi-square')
print("Cramer's value is",res2.loc[2,'results'])
sns.countplot(data = complete_data, x = 'Age_above65_female', hue = 'Survived_cate')
plt.show()
## 寫一個副程式判斷相關性的強度
def judgment_CramerV(df,V):
    if df == 1:
        if V < 0.10:
            qual = 'negligible'
        elif V < 0.30:
            qual = 'small'
        elif V < 0.50:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 2:
        if V < 0.07:
            qual = 'negligible'
        elif V < 0.21:
            qual = 'small'
        elif V < 0.35:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 3:
        if V < 0.06:
            qual = 'negligible'
        elif V < 0.17:
            qual = 'small'
        elif V < 0.29:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 4:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.15:
            qual = 'small'
        elif V < 0.25:
            qual = 'medium'
        else:
            qual = 'large'
    else:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.13:
            qual = 'small'
        elif V < 0.22:
            qual = 'medium'
        else:
            qual = 'large'
    return(qual)

print('The correlation between Survived_cate and Age_above65_:', judgment_CramerV(df,res.loc[2,'results']))
print('The correlation between Survived_cate and Age_above65_female:', judgment_CramerV(df,res2.loc[2,'results']))
# Out:
# 0.24.2
# Age_above65_     N   Y
# Survived_cate
# 0              414  10
# 1              289   1
# Cramer's value is 0.0803
# Age_above65_     N   Y
# Survived_cate
# 0              414  10
# 1              289   1
# Cramer's value is 0.514
# The correlation between Survived_cate and Age_above65_: negligible
# The correlation between Survived_cate and Age_above65_female: large
